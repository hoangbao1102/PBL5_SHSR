# %%
import pandas as pd
import numpy as np
df = pd.read_csv('testat.csv')

# %%
print(df)
# Out:
#                 0             1             2             3             4  \
# 0    -7749.642379  -8122.101390  -8529.705430  -8890.183420  -8770.120416
# 1    -7051.058868  -7260.601567  -7412.144215  -7547.892467  -7691.636491
# 2    -8238.291217  -8436.556353  -8497.044945  -8710.125581  -8598.627129
# 3    -6489.032977  -6768.412471  -6798.859222  -7121.497025  -7107.899311
# 4    -5021.995556  -5112.959387  -5507.980881  -5707.287803  -6120.890330
# ..            ...           ...           ...           ...           ...
# 327 -12090.764380 -12004.418597 -11775.807838 -12274.017755 -12216.699561
# 328 -12831.324351 -12769.802007 -12552.095395 -12924.221707 -13129.809309
# 329 -15590.562140 -15448.737986 -15460.462100 -15567.002716 -15806.634189
# 330  -9809.774097  -9858.358618  -9535.048434  -9650.728652 -10026.646620
# 331 -13660.449623 -13450.247662 -13304.350975 -13482.547074 -14047.654103
#
#                 5             6             7             8             9
# ...

# %%
result = df.loc[(df < -20000).any(axis=1)]

# In kết quả
print(result)
# Out:
#                  0              1              2             3             4  \
# 154 -142304.486009 -142354.434387 -142248.208017 -143491.93982 -147679.17884
#
#                  5              6              7              8              9
# 154 -145085.554022 -143792.088094 -144156.805451 -144619.772154 -143372.257974
